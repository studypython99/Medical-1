# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']
df
# Out:
#        이름   학교  학년    키   국어   영어   수학  과학  사회        sw특기   합계
# 지원번호
# 1번    강나래  구로고   3  197   90   85  100  95  85      Python  455
# 2번    강태원  구로고   3  184   40   35   50  55  25        Java  205
# 3번    강호림  구로고   2  168   80   75   70  80  75  Javascript  380
# 4번    김수찬  구로고   1  187   40   60   70  75  80         NaN  325
# 5번    김재욱  구로고   1  188   15   20   10  35  10         NaN   90
# 6번    박동현  단지고   3  202   80  100   95  85  85          C+  445
# 7번    박혜정  단지고   2  188   55   65   45  40  35      PYTHON  240
# 8번    송근열  단지고   2  190  100   85   90  94  95          c#  464

# %%
x = df['이름']
y1 = df['국어']
y2 = df['영어']
y3 = df['수학']

# %%
plt.bar(x,y1,label='국어')
plt.bar(x,y2,bottom=y1,label='영어')
plt.bar(x,y3,bottom=y1+y2,label='수학')
plt.legend(loc='upper center')

#값표시
for i, txt in enumerate(y1):
    plt.text(x[i],y1[i]-10,txt,ha='center')
for i, txt in enumerate(y2):
    plt.text(x[i],y1[i]+y2[i]-10,txt,ha='center')
for i, txt in enumerate(y3):
    plt.text(x[i],y1[i]+y2[i]+y3[i]-10,txt,ha='center')
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_4652\920271909.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i],y1[i]-10,txt,ha='center')
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_4652\920271909.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i],y1[i]+y2[i]-10,txt,ha='center')
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_4652\920271909.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i],y1[i]+y2[i]+y3[i]-10,txt,ha='center')
