# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']
df
# Out:
#        이름   학교  학년    키   국어   영어   수학  과학  사회        sw특기   합계
# 지원번호
# 1번    강나래  구로고   3  197   90   85  100  95  85      Python  455
# 2번    강태원  구로고   3  184   40   35   50  55  25        Java  205
# 3번    강호림  구로고   2  168   80   75   70  80  75  Javascript  380
# 4번    김수찬  구로고   1  187   40   60   70  75  80         NaN  325
# 5번    김재욱  구로고   1  188   15   20   10  35  10         NaN   90
# 6번    박동현  단지고   3  202   80  100   95  85  85          C+  445
# 7번    박혜정  단지고   2  188   55   65   45  40  35      PYTHON  240
# 8번    송근열  단지고   2  190  100   85   90  94  95          c#  464

# %%
x = df['이름']
y = df['합계']
plt.bar(x,y)
for i , txt in enumerate(y):
    plt.text(x[i],y[i],txt,ha='center')
plt.grid(axis='y',alpha=0.3, ls='--', lw=4, color='purple')
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_10432\3874023974.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i],y[i],txt,ha='center')

# %%
# pie
values = df['합계']
title = df['이름']
plt.pie
