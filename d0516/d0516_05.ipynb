# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import random
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False
import pandas as pd

# %%
import pandas as pd
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']
df
# Out:
#        이름   학교  학년    키   국어   영어   수학  과학  사회        sw특기   합계
# 지원번호
# 1번    강나래  구로고   3  197   90   85  100  95  85      Python  455
# 2번    강태원  구로고   3  184   40   35   50  55  25        Java  205
# 3번    강호림  구로고   2  168   80   75   70  80  75  Javascript  380
# 4번    김수찬  구로고   1  187   40   60   70  75  80         NaN  325
# 5번    김재욱  구로고   1  188   15   20   10  35  10         NaN   90
# 6번    박동현  단지고   3  202   80  100   95  85  85          C+  445
# 7번    박혜정  단지고   2  188   55   65   45  40  35      PYTHON  240
# 8번    송근열  단지고   2  190  100   85   90  94  95          c#  464

# %%
plt.bar(df['이름'],df['국어'])

# %%
plt.plot(df['이름'],df['국어'])

# %%
# subplots(n,n): nxn형태의 그래프 생성
fig,axs = plt.subplots(2,2,figsize=(15,10))

# %%
# subplots(n,n): nxn형태의 그래프 생성
fig,axs = plt.subplots(2,2,figsize=(15,10))

# 0,0 그래프 작성, 좌상단
# 범례: label
axs[0,0].bar(df['이름'],df['국어'],label='국어점수')
# 범례 출력
axs[0,0].legend()
# 상단 타이틀. set.title
axs[0,0].set_title('국어 그래프')
# x,y축
axs[0,0].set(xlabel='이름',ylabel='국어점수')
axs[0,0].set_facecolor('#efefef')
axs[0,0].grid(ls='--',alpha=0.5)

#0,1 그래프 작성
axs[0,1].plot(df['이름'],df['영어'],label='영어점수')
axs[0,1].plot(df['이름'],df['수학'],label='수학점수')

#1.0 그래프 작성
axs[1,0].parh(df['이름'],df['사회'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 21
#      18 axs[0,1].plot(df['이름'],df['수학'],label='수학점수')
#      20 #1.0 그래프 작성
# ---> 21 axs[1,0].parh(df['이름'],df['사회'])
#
# AttributeError: 'Axes' object has no attribute 'parh'
