# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import random
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False
import pandas as pd
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('../z20_data/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# 나이가 50 이상
df['Age']>=50
len(df[df['Age']>=50])
# Out:
# 89

# %%
# 나이가 50 이상이면서 당뇨환자
(df['Age']>=50) & (df['Outcome']==1)
df[(df['Age']>=50) & (df['Outcome']==1)].count()
# Out:
# Pregnancies                 43
# Glucose                     43
# BloodPressure               43
# SkinThickness               43
# Insulin                     43
# BMI                         43
# DiabetesPedigreeFunction    43
# Age                         43
# Outcome                     43
# dtype: int64

# %%
#상관관계 표시, 1과 가까울수록 상관관계가 크다
data_corr = df.corr()
fig = plt.figure(figsize=(8,8))
sns.heatmap(data_corr,annot=True)
# Out:
# <Axes: >

# %%
df['Outcome'] ==1
out_1 = df[df['Outcome'] ==1].count()
out_0 = df[df['Outcome'] !=1].count()
out_1
# Out:
# Pregnancies                 268
# Glucose                     268
# BloodPressure               268
# SkinThickness               268
# Insulin                     268
# BMI                         268
# DiabetesPedigreeFunction    268
# Age                         268
# Outcome                     268
# dtype: int64

# %%
df['Outcome'].value_counts().values
# Out:
# array([500, 268], dtype=int64)

# %%
# 당뇨병환자비율 원그래프
df['Outcome'] ==1
df[df['Outcome'] ==1].count() # 268명

values = df['Outcome'].value_counts().values
labels = ['dangnyoO', 'dangnyoX']
plt.pie(values,labels=labels,autopct='%.1f%%')
plt.title("DANGNYO")
# Out:
# Text(0.5, 1.0, 'DANGNYO')

# %%
# 21~30세 인원 출력
(df['Age']>=21) & (df['Age']<=30)
df[(df['Age']>=21) & (df['Age']<=30)].count()
len(df[(df['Age']>=21) & (df['Age']<=30)])
df[(df['Age']<=30)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
# 히스토그램 그래프
# 1개 데이터의 대략적인 구성을 보여줌
df['Age'].hist()
# Out:
# <Axes: >

# %%
# 컬럼의 데이터 구성을 확인
df.hist(figsize=(14,14))
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)
